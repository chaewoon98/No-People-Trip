# %%
import numpy as np

# %%
import tensorflow as tf

# %%
import pandas as pd

# %%
from fbprophet import Prophet

# %%
from pandas.io.parsers import read_csv

# %%
df = pd.read_csv("D:\FB1_data.csv", sep = ",")

# %%
df['cap']=30000
df['floor']=100

# %%
m = Prophet(growth='logistic')

# %%
df.head(3)
# Out:
#            ds     y    cap  floor
# 0  2018-01-01  3703  30000    100
# 1  2018-01-02  3519  30000    100
# 2  2018-01-03  1808  30000    100

# %%
m.fit(df)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=100)
future['cap']=30000
future['floor']=100

# %%
forecast = m.predict(future)

# %%
fig1 = m.plot(forecast)

# %%
from fbprophet.plot import add_changepoints_to_plot

# %%
fig = m.plot(forecast)

# %%
newyears = pd.DataFrame({
  'holiday': 'newyear',
  'ds': pd.to_datetime(['2011-01-01', '2012-01-01', '2013-01-01',
                        '2014-01-01', '2015-01-01', '2016-01-01',
                        '2017-01-01', '2018-01-01', '2019-01-01',
                        '2020-01-01']),
  'lower_window': 0,
  'upper_window': 1,
})
lunarnewyears = pd.DataFrame({
  'holiday': 'newyear',
  'ds': pd.to_datetime(['2011-02-02', '2011-02-03', '2011-02-04',
                        '2012-01-22', '2012-01-23', '2012-01-24',
                        '2013-02-09', '2013-02-10', '2013-02-11',
                        '2014-01-30', '2014-01-31', '2014-02-01',
                        '2015-02-18', '2015-02-19', '2015-02-20',
                        '2016-02-06', '2016-02-07', '2016-02-08',
                        '2016-02-09', '2016-02-10', '2017-01-27',
                        '2017-01-28', '2017-01-29', '2017-01-30',
                        '2018-02-15', '2018-02-16', '2018-02-17',
                        '2019-02-04', '2019-02-05', '2019-02-06',
                        '2020-01-24', '2020-01-25', '2020-01-26']),
  'lower_window': 0,
  'upper_window': 1,
})
independencemovementdays = pd.DataFrame({
  'holiday': 'independencemovementday',
  'ds': pd.to_datetime(['2011-03-01', '2012-03-01', '2013-03-01',
                        '2014-03-01', '2015-03-01', '2016-03-01',
                        '2017-03-01', '2018-03-01', '2019-03-01',
                        '2020-03-01']),
  'lower_window': 0,
  'upper_window': 1,
})
childrendays = pd.DataFrame({
  'holiday': 'childrendays',
  'ds': pd.to_datetime(['2011-05-05', '2012-05-05', '2013-05-05',
                        '2014-05-05', '2015-05-05', '2016-05-05',
                        '2017-05-05', '2018-05-05', '2019-05-05',
                        '2020-05-05']),
  'lower_window': 0,
  'upper_window': 1,
})
buddabirthdays = pd.DataFrame({
  'holiday': 'buddabirthday',
  'ds': pd.to_datetime(['2011-05-10', '2012-05-28', '2013-05-17',
                        '2014-05-06', '2015-05-25', '2016-05-14',
                        '2017-05-03', '2018-05-22', '2019-05-12',
                        '2020-04-30']),
  'lower_window': 0,
  'upper_window': 1,
})
memorialdays = pd.DataFrame({
  'holiday': 'memorialday',
  'ds': pd.to_datetime(['2011-06-06', '2012-06-06', '2013-06-06',
                        '2014-06-06', '2015-06-06', '2016-06-06',
                        '2017-06-06', '2018-06-06', '2019-06-06',
                        '2020-06-06']),
  'lower_window': 0,
  'upper_window': 1,
})
liberationdays = pd.DataFrame({
  'holiday': 'liberationday',
  'ds': pd.to_datetime(['2011-08-15', '2012-08-15', '2013-08-15',
                        '2014-08-15', '2015-08-15', '2016-08-15',
                        '2017-08-15', '2018-08-15', '2019-08-15',
                        '2020-08-15']),
  'lower_window': 0,
  'upper_window': 1,
})
thanksgivingdays = pd.DataFrame({
  'holiday': 'thanksgivingday',
  'ds': pd.to_datetime(['2011-09-11', '2011-09-12', '2011-09-13',
                        '2012-09-29', '2012-09-30', '2012-10-01',
                        '2013-09-18', '2013-09-19', '2013-09-20',
                        '2014-09-07', '2014-09-08', '2014-09-09',
                        '2015-09-26', '2015-09-27', '2015-09-28',
                        '2016-09-14', '2016-09-15', '2016-09-16',
                        '2016-09-17', '2016-09-18', '2017-10-04',
                        '2017-10-05', '2017-10-06', '2018-09-23',
                        '2018-09-24', '2018-09-25', '2019-09-12',
                        '2019-09-13', '2019-09-14', '2020-09-30']),

  'lower_window': 0,
  'upper_window': 1,
})
nationalfoundationdays = pd.DataFrame({
  'holiday': 'nationalfoundationday',
  'ds': pd.to_datetime(['2011-10-03', '2012-10-03', '2013-10-03',
                        '2014-10-03', '2015-10-03', '2016-10-03',
                        '2017-10-03', '2018-10-03', '2019-10-03',
                        '2020-10-03']),
  'lower_window': 0,
  'upper_window': 1,
})
koreandays = pd.DataFrame({
  'holiday': 'koreanday',
  'ds': pd.to_datetime(['2013-10-09', '2014-10-09', '2015-10-09',                        
                        '2016-10-09', '2017-10-09', '2018-10-09',
                        '2020-10-09','2020-10-09']),
  'lower_window': 0,
  'upper_window': 1,
})
crismasdays = pd.DataFrame({
  'holiday': 'crismasday',
  'ds': pd.to_datetime(['2011-12-25', '2012-12-25', '2013-12-25',
                        '2014-12-25', '2015-12-25', '2016-12-25',
                        '2017-12-25', '2018-12-25', '2019-12-25',
                        '2020-12-25']),
  'lower_window': 0,
  'upper_window': 1,
})

holidays = pd.concat((newyears, lunarnewyears, independencemovementdays,
childrendays, buddabirthdays, memorialdays, liberationdays,
thanksgivingdays, nationalfoundationdays, koreandays,
crismasdays))

# %%
import plotly.plotly as py

# %%
import plotly.offline as py

# %%
from fbprophet.plot import plot_plotly

# %%
m = Prophet(changepoints=['2020-02-12'])

# %%
m = Prophet(
    # trend
    changepoint_prior_scale=0.9,
    # seasonality
    weekly_seasonality=10,
    yearly_seasonality = 20,
    daily_seasonality=False,
    seasonality_mode='multiplicative',
)

m.fit(df)
forecast = m.predict(future)

fig = plot_plotly(m, forecast) 
py.iplot(fig)

# %%
m = Prophet(changepoints=['2020-02-12'])
m = Prophet(changepoints=['2020-04-07'])

# %%
m = Prophet(changepoint_range=0.9)

# %%
m = Prophet(# holiday
    holidays= holidays,
    holidays_prior_scale=0.5)

# %%
m.fit(df)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast = m.predict(future)
forecast[['ds','yhat','yhat_lower','yhat_upper']]
# Out:
#             ds         yhat   yhat_lower   yhat_upper
# 0   2018-01-01  7288.884518  4643.897048  9547.013592
# 1   2018-01-02  6638.073736  4144.412421  9207.710680
# 2   2018-01-03   702.499800 -1815.280791  3149.718577
# 3   2018-01-04   -39.819600 -2320.304300  2296.910184
# 4   2018-01-05   778.170228 -1605.420381  3269.672338
# ..         ...          ...          ...          ...
# 856 2020-09-02 -1838.143461 -4355.309132   762.868972
# 857 2020-09-03 -2733.939623 -5163.801240  -342.135767
# 858 2020-09-04 -2069.454639 -4520.707371   343.400588
# 859 2020-09-05  -117.220326 -2398.395036  2260.468601
# 860 2020-09-06 -1264.655696 -3620.237329  1261.232511
#
# [861 rows x 4 columns]

# %%
m.predict()
# Out:
#             ds        trend    cap   yhat_lower   yhat_upper  trend_lower  \
# 0   2018-01-01  3283.276910  30000  4809.815345  9709.666353  3283.276910
# 1   2018-01-02  3295.715151  30000  4268.470159  8970.052585  3295.715151
# 2   2018-01-03  3308.153392  30000 -1770.786117  3055.807538  3308.153392
# 3   2018-01-04  3320.591633  30000 -2512.763502  2415.033982  3320.591633
# 4   2018-01-05  3333.029874  30000 -1874.245550  3000.028110  3333.029874
# ..         ...          ...    ...          ...          ...          ...
# 756 2020-05-24   287.822113  30000  -715.967123  4070.595212   287.822113
# 757 2020-05-26   263.492032  30000 -1022.291888  3903.910578   263.492032
# 758 2020-05-27   251.326991  30000 -1589.252085  3251.890653   251.326991
# 759 2020-05-28   239.161951  30000 -2514.272402  2428.379666   239.161951
# 760 2020-05-29   226.996910  30000 -1810.825191  3166.692329   226.996910
#
#      trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# ...

# %%
forecast
# Out:
#             ds        trend    cap   yhat_lower   yhat_upper  trend_lower  \
# 0   2018-01-01  3283.276910  30000  4643.897048  9547.013592  3283.276910
# 1   2018-01-02  3295.715151  30000  4144.412421  9207.710680  3295.715151
# 2   2018-01-03  3308.153392  30000 -1815.280791  3149.718577  3308.153392
# 3   2018-01-04  3320.591633  30000 -2320.304300  2296.910184  3320.591633
# 4   2018-01-05  3333.029874  30000 -1605.420381  3269.672338  3333.029874
# ..         ...          ...    ...          ...          ...          ...
# 856 2020-09-02  -940.846981  30000 -4355.309132   762.868972 -1062.672198
# 857 2020-09-03  -953.012022  30000 -5163.801240  -342.135767 -1077.558974
# 858 2020-09-04  -965.177062  30000 -4520.707371   343.400588 -1094.126499
# 859 2020-09-05  -977.342103  30000 -2398.395036  2260.468601 -1108.418692
# 860 2020-09-06  -989.507143  30000 -3620.237329  1261.232511 -1122.883582
#
#      trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# ...

# %%
m.plot(forecast)

# %%
forecast.to_csv("D:\창경궁시계열6.csv")

# %%
from fbprophet.plot import plot_yearly

# %%
a = plot_yearly(m)
